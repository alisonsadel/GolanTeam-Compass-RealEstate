# %% [markdown]
# ### Part Three - Subway Station Geopy API

# %% [markdown]
# #### Set-Up

# %%
# Import Dependencies
import pandas as pd
import numpy as np

# For API Call
import geopy
from geopy import distance
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import geopandas as gpd
import geopy
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# To estimate time and progress during loop
from tqdm._tqdm_notebook import tqdm_notebook
from tqdm import tqdm
tqdm.pandas()

# Remove dataFrame display size restrictions
#pd.set_option("display.max_rows", None, "display.max_columns", None)

# Create path
path = "Resources/stations.csv"

# Read in csv
df = pd.read_csv(path)

# To save dataframe as png
import dataframe_image as dfi

# Grab original dimensions before clean
original_dimensions = df.shape
print(f'Original dimensions of the subway stations site dataset (rows/columns): {original_dimensions}')
# Out:
# <ipython-input-1-3f10e11d9eb9>:18: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`
#   from tqdm._tqdm_notebook import tqdm_notebook
# Original dimensions of the subway stations site dataset (rows/columns): (496, 15)

# %%
df.head()
# Out:
#    Station ID  Complex ID GTFS Stop ID Division     Line  \
# 0           1           1          R01      BMT  Astoria
# 1           2           2          R03      BMT  Astoria
# 2           3           3          R04      BMT  Astoria
# 3           4           4          R05      BMT  Astoria
# 4           5           5          R06      BMT  Astoria
#
#               Stop Name Borough Daytime Routes Structure  GTFS Latitude  \
# 0  Astoria-Ditmars Blvd       Q            N W  Elevated      40.775036
# 1          Astoria Blvd       Q            N W  Elevated      40.770258
# 2                 30 Av       Q            N W  Elevated      40.766779
# 3              Broadway       Q            N W  Elevated      40.761820
# 4                 36 Av       Q            N W  Elevated      40.756804
#
#    GTFS Longitude   North Direction Label South Direction Label  ADA ADA Notes
# 0      -73.912034                     NaN             Manhattan    0       NaN
# 1      -73.917843            Ditmars Blvd             Manhattan    1       NaN
# 2      -73.921479  Astoria - Ditmars Blvd             Manhattan    0       NaN
# 3      -73.925508  Astoria - Ditmars Blvd             Manhattan    0       NaN
# 4      -73.929575  Astoria - Ditmars Blvd             Manhattan    0       NaN

# %% [markdown]
# #### Clean Up

# %%
# Remove irrelevant columns
df = df[df.columns.difference(['Complex ID', 'Structure', 'Division', 'GTFS Stop ID', 'North Direction Label', 'South Direction Label', 'ADA Notes'])]

columns_removed = df.shape
print(f'The dimensions of the subway stations site dataset after removing irrelevant columns: {columns_removed}')
# Out:
# The dimensions of the subway stations site dataset after removing irrelevant columns: (496, 8)

# %%
# Change each Borough Designation Initial to the full Borough for consistency with other dataframes
df['Borough'] = df['Borough'].str.replace('Q', 'queens')
df['Borough'] = df['Borough'].str.replace('M', 'manhattan')
df['Borough'] = df['Borough'].str.replace('Bk', 'brooklyn')
df['Borough'] = df['Borough'].str.replace('Bx', 'bronx')
df['Borough'] = df['Borough'].str.replace('SI', 'staten island')

# %%
# Rename column names
df = df.rename(columns={"ADA": "ada_access","Borough": "borough", "GTFS Latitude": "lat_field", "GTFS Longitude": "lon_field", "Line": "line", "Station ID": "station_id", "Stop Name": "station_name"}) 

# Convert all strings to lowercase
df["line"] = df["line"].str.lower()
df["station_name"] = df["station_name"].str.lower()

# %%
# Display first 5 records
df.head()
# Out:
#    ada_access borough Daytime Routes  lat_field  lon_field     line  \
# 0           0  queens            N W  40.775036 -73.912034  astoria
# 1           1  queens            N W  40.770258 -73.917843  astoria
# 2           0  queens            N W  40.766779 -73.921479  astoria
# 3           0  queens            N W  40.761820 -73.925508  astoria
# 4           0  queens            N W  40.756804 -73.929575  astoria
#
#    station_id          station_name
# 0           1  astoria-ditmars blvd
# 1           2          astoria blvd
# 2           3                 30 av
# 3           4              broadway
# 4           5                 36 av

# %% [markdown]
# #### Add Categorical Encoding & Binary Values

# %%
# ADA Accessible is denoted by 1
# Not Accessible is denoted by 0
# Partially Accessible is denoted by 2

# Convert type of columns to 'category'
df['ada_access'] = df['ada_access'].astype('category')

# Assigning numerical values and store in another column
df['ada_level'] = df['ada_access'].cat.codes
df['ada_level'].value_counts()
# Out:
# 0    359
# 1    128
# 2      9
# Name: ada_level, dtype: int64

# %%
# Generate binary values using get_dummies for ada accessibility 
dum_df = pd.get_dummies(df, columns=["ada_access"], prefix=["access_type_is"] )

# Merge with main df
df = df.merge(dum_df)

# Rename columns to display whether the station is fully, partially or NOT ada-accessible (i.e. is there an elevator on both platforms?)
df = df.rename(columns={"access_type_is_0": "ada_access_no", "access_type_is_1": "ada_access_yes", "access_type_is_2": "ada_access_partial"})

# %% [markdown]
# #### Make API Call to Obtain Zipcodes
# * We need zipcodes appended to the dataframe in order to determine the closest subway station to each property

# %%
geolocator = Nominatim(user_agent="alison.sadel@gmail.com")

# 
reverse = RateLimiter(geolocator.reverse, min_delay_seconds=.01)

# Find the exact location of each subway station using latitude and longitude coordinate pairs
df['location'] = df.progress_apply(lambda row: reverse((row['lat_field'], row['lon_field'])),axis=1)
# Out:
# 100%|██████████| 496/496 [04:08<00:00,  2.00it/s]

# %%
# Display results of API call
df['location']
# Out:
# 0      (Astoria-Ditmars Boulevard, 31st Street, Stein...
# 1      (Astoria Boulevard, Hoyt Avenue South, Queens,...
# 2      (30th Avenue, 31st Street, Queens, Queens Coun...
# 3      (Broadway, 31st Street, Queens, Queens County,...
# 4      (35-53, 31st Street, Ravenswood, Queens, Queen...
#                              ...
# 491    (Prince's Bay, Holton Avenue, Princes Bay, Sta...
# 492    (Pleasant Plains, Station Avenue, Pleasant Pla...
# 493    (Richmond Valley, Richmond Valley Road, Richmo...
# 494    (Tottenville, Bentley Street, Tottenville, Sta...
# 495    (Arthur Kill, Ellis Street, Tottenville, State...
# Name: location, Length: 496, dtype: object

# %%
# Function to add zipcode column
def parse_zipcode(location):
    if location and location.raw.get('address') and location.raw['address'].get('postcode'):
        return location.raw['address']['postcode']
    else:
        return None
df['zipcode'] = df['location'].apply(parse_zipcode)

df
# Out:
#     ada_access        borough Daytime Routes  lat_field  lon_field  \
# 0            0         queens            N W  40.775036 -73.912034
# 1            1         queens            N W  40.770258 -73.917843
# 2            0         queens            N W  40.766779 -73.921479
# 3            0         queens            N W  40.761820 -73.925508
# 4            0         queens            N W  40.756804 -73.929575
# ..         ...            ...            ...        ...        ...
# 491          0  staten island            SIR  40.525507 -74.200064
# 492          0  staten island            SIR  40.522410 -74.217847
# 493          0  staten island            SIR  40.519631 -74.229141
# 494          1  staten island            SIR  40.512764 -74.251961
# 495          1  staten island            SIR  40.516578 -74.242096
#
#               line  station_id          station_name  ada_level  \
# 0          astoria           1  astoria-ditmars blvd          0
# 1          astoria           2          astoria blvd          1
# 2          astoria           3                 30 av          0
# 3          astoria           4              broadway          0
# 4          astoria           5                 36 av          0
# ..             ...         ...                   ...        ...
# 491  staten island         517          prince's bay          0
# 492  staten island         518       pleasant plains          0
# 493  staten island         519       richmond valley          0
# 494  staten island         522           tottenville          1
# 495  staten island         523           arthur kill          1
#
#      ada_access_no  ada_access_yes  ada_access_partial  \
# 0                1               0                   0
# 1                0               1                   0
# 2                1               0                   0
# 3                1               0                   0
# 4                1               0                   0
# ..             ...             ...                 ...
# 491              1               0                   0
# 492              1               0                   0
# 493              1               0                   0
# 494              0               1                   0
# 495              0               1                   0
#
#                                               location zipcode
# 0    (Astoria-Ditmars Boulevard, 31st Street, Stein...   11101
# 1    (Astoria Boulevard, Hoyt Avenue South, Queens,...   11102
# 2    (30th Avenue, 31st Street, Queens, Queens Coun...   11102
# 3    (Broadway, 31st Street, Queens, Queens County,...   11101
# 4    (35-53, 31st Street, Ravenswood, Queens, Queen...   11106
# ..                                                 ...     ...
# 491  (Prince's Bay, Holton Avenue, Princes Bay, Sta...   10309
# 492  (Pleasant Plains, Station Avenue, Pleasant Pla...   10309
# 493  (Richmond Valley, Richmond Valley Road, Richmo...   10307
# 494  (Tottenville, Bentley Street, Tottenville, Sta...   10307
# 495  (Arthur Kill, Ellis Street, Tottenville, State...   10307
#
# [496 rows x 14 columns]

# %%
# Ensure zipcodes are only 5 characters in length
df['zipcode'] = df['zipcode'].str[:5]

# Remove 'None' value in zipcode column
df = df[df.zipcode.str.contains("None") == False]

# Check work
# %pprint
df['zipcode'].tolist()
# Out:
# Pretty printing has been turned OFF
# ['11101', '11102', '11102', '11101', '11106', '11101', '10022', '10019', '10019', '10019', '10036', '10019', '10001', '10010', '10003', '10003', '10003', '10003', '10013', '10003', '10007', '10006', '10004', '11201', '11201', '11201', '11217', '11217', '11209', '11215', '11232', '11209', '11220', '11220', '11204', '11220', '11209', '11209', '11209', '11217', '11217', '11225', '11225', '11235', '11226', '11226', '11226', '11230', '11234', '11230', '11234', '11235', '11235', '11235', '11235', '11235', '11224', '11224', '11220', '11219', '11219', '11214', '11214', '11214', '11214', '11214', '11223', '11214', '11214', '11224', '11220', '11204', '11204', '11204', '11204', '11223', '11223', '11223', '11223', '11418', '11418', '11418', '11421', '11421', '11421', '11208', '11208', '11208', '11208', '11207', '11208', '11207', '11207', '11207', '11207', '11207', '11207', '11206', '11207', '11211', '11211', '10002', '10002', '10013', '10000', '10003', '10004', '11385', '11385', '11385', '11385', '11385', '11237', '11221', '10011', '10011', '10003', '10003', '10009', '11211', '11211', '11211', '11207', '11206', '11206', '11237', '11385', '11418', '11385', '11207', '11207', '11207', '11207', '11207', '11207', '11207', '11236', '11236', '11216', '11233', '11213', '10034', '10040', '10040', '10040', '10033', '10032', '10032', '10040', '10040', '10040', '10040', '10027', '10039', '10026', '10025', '10025', '10024', '10024', '10023', '10019', '10019', '10036', '10001', '10011', '10011', '10014', '10014', '10012', '10019', '10007', '10007', '10279', '11201', '11201', '11217', '11207', '11207', '11207', '11216', '11207', '11207', '11207', '11207', '11207', '11207', '11207', '11208', '11208', '11208', '11419', '11419', '11419', '11419', '11419', '11420', '11417', '11414', '11414', '11693', '11693', '11693', '11693', '11694', '11692', '11692', '11692', '11691', '11691', '11691', '10467', '10458', '10468', '10468', '10457', '10457', '10453', '10452', '10452', '10452', '10039', '11101', '10044', '10021', '10019', '10019', '10019', '10019', '10011', '10019', '10002', '10002', '10003', '10002', '10002', '11201', '11231', '11231', '11215', '11215', '11215', '11215', '11218', '11223', '11223', '11223', '11223', '11230', '11223', '11223', '11223', '11223', '11223', '11224', '11427', '11427', '11427', '11427', '11415', '11415', '11375', '11375', '11375', '11374', '11374', '11373', '11373', '11373', '11377', '11373', '11103', '11103', '11101', '11101', '11101', '10022', '10019', '10019', '11433', '11433', '11435', '11101', '11101', '11222', '11222', '11211', '11211', '11211', '11216', '11221', '11221', '11221', '11221', '10471', '10463', '10463', '10463', '10034', '10034', '10040', '10040', '10033', '10031', '10032', '10031', '10031', '10115', '10027', '10025', '10025', '10025', '10024', '10023', '10023', '10023', '10107', '10036', '10001', '10001', '10011', '10001', '10001', '10014', '10014', '10014', '10013', '10012', '10007', '10006', '10004', '10007', '10003', '10038', '11201', '11231', '11207', '11227', '11217', '11213', '11215', '11238', '11225', '11225', '11225', '11213', '11212', '11207', '11207', '11207', '11207', '11207', '11207', '11225', '11225', '11225', '11235', '11226', '11235', '11234', '10461', '10461', '10461', '10461', '10462', '10461', '10472', '10472', '10472', '10472', '10459', '10459', '10458', '10458', '10454', '10454', '10454', '10454', '10468', '10467', '10458', '10468', '10468', '10453', '10453', '10468', '10452', '10468', '10452', '10452', '10451', '10451', '10037', '10037', '10029', '10037', '10037', '10037', '10037', '10037', '10037', '10037', '10017', '10016', '10016', '10010', '10003', '10003', '10012', '10012', '10013', '10000', '10003', '10003', '10003', '11201', '10470', '10470', '10470', '10466', '10467', '10467', '10467', '10467', '10462', '10462', '10460', '10460', '10458', '10458', '10459', '10459', '10459', '10459', '10455', '10451', '10039', '10037', '10030', '10027', '10037', '10037', '10466', '10466', '10469', '10 ...

# %%
# Print final number of rows and columns
final_length = len(df)
final_column_length = len(df.columns)

print(f'After preprocessing the dataframe, creating classifications and calling an API to create a zipcode colum, there are {final_length} subway station records and {final_column_length} fields.')
# Out:
# After preprocessing the dataframe, creating classifications and calling an API to create a zipcode colum, there are 494 subway station records and 14 fields.

# %%
# Label index header 'index'
df.index.name = 'index'

# %%
# Display final clean dataframe
df.head()
# Out:
#       ada_access borough Daytime Routes  lat_field  lon_field     line  \
# index
# 0              0  queens            N W  40.775036 -73.912034  astoria
# 1              1  queens            N W  40.770258 -73.917843  astoria
# 2              0  queens            N W  40.766779 -73.921479  astoria
# 3              0  queens            N W  40.761820 -73.925508  astoria
# 4              0  queens            N W  40.756804 -73.929575  astoria
#
#        station_id          station_name  ada_level  ada_access_no  \
# index
# 0               1  astoria-ditmars blvd          0              1
# 1               2          astoria blvd          1              0
# 2               3                 30 av          0              1
# 3               4              broadway          0              1
# 4               5                 36 av          0              1
#
#        ada_access_yes  ada_access_partial  \
# index
# 0                   0                   0
# 1                   1                   0
# 2                   0                   0
# 3                   0                   0
# 4                   0                   0
#
#                                                 location zipcode
# index
# 0      (Astoria-Ditmars Boulevard, 31st Street, Stein...   11101
# 1      (Astoria Boulevard, Hoyt Avenue South, Queens,...   11102
# 2      (30th Avenue, 31st Street, Queens, Queens Coun...   11102
# 3      (Broadway, 31st Street, Queens, Queens County,...   11101
# 4      (35-53, 31st Street, Ravenswood, Queens, Queen...   11106

# %%
# Export image display first 5 records
sample = df[0:5]
#df.sample(n=5)
 
dfi.export(sample, 'subway_dataframe.png')

# %%
# Export to csv 
df.to_csv("Resources/stations_clean.csv")
