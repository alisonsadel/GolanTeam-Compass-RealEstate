# %% [markdown]
# ## Part 2 - Geocoding API

# %%
# Import libraries
import pandas as pd
import numpy as np

# For Part 1b API Call
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent= 'alison.sadel@gmail.com')
from geopy.extra.rate_limiter import RateLimiter
import webbrowser

# To see full column values
pd.set_option('max_colwidth', 800)

# %%
# Create path
file = "Resources/clean.csv"

# Read in file
df = pd.read_csv(file)

# Drop 2nd index
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

df
# Out:
#                    Street       Unit    Borough                Neighborhood  \
# 0         9602 4th Avenue         6D   Brooklyn                   Bay Ridge
# 1        94 Degraw Street        NaN   Brooklyn  Columbia Street Waterfront
# 2    933 Lafayette Street  1st floor   Brooklyn          Bedford-Stuyvesant
# 3       918 Manhattan Ave         #2   Brooklyn                  Greenpoint
# 4      906 Prospect Place         2A   Brooklyn               Crown Heights
# ..                    ...        ...        ...                         ...
# 231  308 East 38th Street         4C  Manhattan                 Murray Hill
# 232  308 East 38th Street         8D  Manhattan                 Murray Hill
# 233  308 East 38th Street        16F  Manhattan                 Murray Hill
# 234  308 East 38th Street        11E  Manhattan                 Murray Hill
# 235  439 East 88th Street         4F  Manhattan             Upper East Side
#
#          City     State        Year      Price  Status  Postalcode  \
# 0    New York  New York  2019-01-01        NaN  Rental       11209
# 1    Brooklyn  New York  2020-01-01  2350000.0    Sale       11231
# 2    Brooklyn  New York  2020-01-01  1095000.0    Sale       11221
# 3    Brooklyn  New York  2021-01-01     5000.0  Rental       11222
# 4    Brooklyn  New York  2021-01-01   735000.0    Sale       11213
# ..        ...       ...         ...        ...     ...         ...
# 231  New York  New York  2018-01-01   890000.0    Sale       10016
# 232  New York  New York  2018-01-01   899000.0    Sale       10016
# 233  New York  New York  2018-01-01  1556238.0    Sale       10016
# 234  New York  New York  2018-01-01  1374723.0    Sale       10016
# 235  New York  New York  2018-01-01   810000.0    Sale       10016
#
#                                             Location
# 0         9602 4th Avenue, New York, New York, 11209
# 1        94 Degraw Street, Brooklyn, New York, 11231
# 2    933 Lafayette Street, Brooklyn, New York, 11221
# 3       918 Manhattan Ave, Brooklyn, New York, 11222
# 4      906 Prospect Place, Brooklyn, New York, 11213
# ..                                               ...
# 231  308 East 38th Street, New York, New York, 10016
# 232  308 East 38th Street, New York, New York, 10016
# 233  308 East 38th Street, New York, New York, 10016
# 234  308 East 38th Street, New York, New York, 10016
# 235  439 East 88th Street, New York, New York, 10016
#
# [236 rows x 11 columns]

# %%
# 1
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

# %%
# 2

df['Address'] = df['Location'].apply(geocode)

# %%
df

# %%
# 3 
df['point'] = df['Address'].apply(lambda loc: tuple(loc.point) if loc else None)
df.point

# %%
df.point

# %%
# 4a - Extract Data as Series
coordinates_series = df['point'].apply(pd.Series)
coordinates_series

#4b - Add Latitude and Longitude as columns in dataframe
df['Latitude'] = coordinates_series[0]

df['Longitude'] = coordinates_series[1]

#4c - Find Missing Values
# Find None Values by Creating a bool series True for NaN values 
bool_series = pd.isnull(df["Latitude"]) 
#bool_series = pd.isnull(full["Longitude"]) 

# Display data only where columns = NaN 
df[bool_series]

# 4d Add missing values in Lat/Long columns

df.loc[2,'Latitude'] = 40.692015
df.loc[2,'Longitude'] = -73.934678

df.loc[31,'Latitude'] = 40.619061
df.loc[31,'Longitude'] = -73.955139

df.loc[104,'Latitude'] = 40.77844
df.loc[104,'Longitude'] = -73.945538

df

# %%
df.to_csv("Resources/geopyoutput.csv")
